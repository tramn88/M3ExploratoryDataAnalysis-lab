# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify the distribution of data in the dataset.
#
# -   Identify outliers in the dataset.
#
# -   Remove outliers from the dataset.
#
# -   Identify correlation between features in the dataset.

# %% [markdown]
# * * *

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import pandas as pd

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
# your code goes here
import matplotlib.pyplot as plt
# Plot the distribution curve for the 'ConvertedComp' column
plt.figure(figsize=(10, 6))  # Set the figure size
plt.hist(df['ConvertedComp'], bins=50, edgecolor='k')  # Plot the histogram
plt.xlabel('Converted Compensation')  # Set the x-axis label
plt.ylabel('Frequency')  # Set the y-axis label
plt.title('Distribution of Converted Compensation')  # Set the title
plt.show()  # Display the plot

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
# your code goes here
# Plot the histogram for the 'ConvertedComp' column
plt.hist(df['ConvertedComp'], bins=30, edgecolor='k')
plt.xlabel('Converted Compensation')
plt.ylabel('Frequency')
plt.title('Histogram of Converted Compensation')
plt.show()

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
# your code goes here
# Calculate the median of the 'ConvertedComp' column
median_converted_comp = df['ConvertedComp'].median()

# Print the result
print("Median ConvertedComp:", median_converted_comp)
# Out:
# Median ConvertedComp: 57745.0

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
# your code goes here
# Filter the dataframe to select responders who identified themselves only as a man
man_responders = df[df['Gender'] == 'Man']

# Count the number of responders who identified themselves only as a man
num_man_responders = len(man_responders)

# Print the result
print("Number of responders identified as Man:", num_man_responders)
# Out:
# Number of responders identified as Man: 10480

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
# your code goes here
# Filter the dataframe to select responders identified as only a woman
woman_responders = df[df['Gender'] == 'Woman']

# Calculate the median ConvertedComp for the woman responders
median_converted_comp_woman = woman_responders['ConvertedComp'].median()

# Print the result
print("Median ConvertedComp for responders identified as Woman:", median_converted_comp_woman)
# Out:
# Median ConvertedComp for responders identified as Woman: 57708.0

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
# your code goes here
# Calculate the five-number summary for the 'Age' column
age_summary = df['Age'].describe().loc[['min', '25%', '50%', '75%', 'max']]

# Print the result
print("Five-number summary for the 'Age' column:")
print(age_summary)
# Out:
# Five-number summary for the 'Age' column:
# min    16.0
# 25%    25.0
# 50%    29.0
# 75%    35.0
# max    99.0
# Name: Age, dtype: float64

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
# your code goes here
# Plot the histogram for the 'Age' column
plt.hist(df['Age'], bins=30, edgecolor='k')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Age')
plt.show()

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
# your code goes here
# Create a box plot for the 'ConvertedComp' column
df['ConvertedComp'].plot(kind='box')

# Set the title and labels for the plot
plt.title('Box Plot of ConvertedComp')
plt.ylabel('Converted Compensation')

# Display the plot
plt.show()

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
# your code goes here
# Calculate the interquartile range for the 'ConvertedComp' column
Q1 = df['ConvertedComp'].quantile(0.25)  # First quartile
Q3 = df['ConvertedComp'].quantile(0.75)  # Third quartile
IQR = Q3 - Q1  # Interquartile range

# Print the result
print("Interquartile Range (IQR) for ConvertedComp:", IQR)
# Out:
# Interquartile Range (IQR) for ConvertedComp: 73132.0

# %% [markdown]
# Find out the upper and lower bounds.

# %%
# your code goes here
# Calculate the upper and lower bounds
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)

# Print the results
print("Lower bound:", lower_bound)
print("Upper bound:", upper_bound)
# Out:
# Lower bound: -82830.0
# Upper bound: 209698.0

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
# your code goes here
# Count the number of outliers
outliers = df[(df['ConvertedComp'] < lower_bound) | (df['ConvertedComp'] > upper_bound)]
num_outliers = len(outliers)

# Print the result
print("Number of outliers in ConvertedComp column:", num_outliers)

# Calculate the median of the 'ConvertedComp' column
median_before = df['ConvertedComp'].median()
# Print the result
print("Median ConvertedComp before removing outliers:", median_before)

# Calculate the median of the 'ConvertedComp' column in the new dataframe
median_after = new_df['ConvertedComp'].median()
# Print the result
print("Median ConvertedComp after removing outliers:", median_after)

# Calculate the mean of the 'ConvertedComp' column in the new dataframe
mean_after = new_df['ConvertedComp'].mean()
# Print the result
print("Mean ConvertedComp after removing outliers:", mean_after)
# Out:
# Number of outliers in ConvertedComp column: 879
# Median ConvertedComp before removing outliers: 57745.0
# Median ConvertedComp after removing outliers: 52704.0
# Mean ConvertedComp after removing outliers: 59883.20838915799

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
# your code goes here
# Create a new dataframe by removing outliers
new_df = df[(df['ConvertedComp'] >= lower_bound) & (df['ConvertedComp'] <= upper_bound)]

# Print the number of rows in the new dataframe
print("Number of rows in the new dataframe:", len(new_df))
# Out:
# Number of rows in the new dataframe: 9703

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
# your code goes here
# Calculate the correlation matrix
correlation_matrix = df.corr()

# Select the correlation values for the 'Age' column
age_correlation = correlation_matrix['Age']

# Print the correlation values
print(age_correlation)
# Out:
# Respondent              0.004041
# CompTotal               0.006970
# ConvertedComp           0.105386
# WorkWeekHrs             0.036518
# CodeRevHrs             -0.020469
# Age                     1.000000
# ConvertedCompPerWeek    0.105386
# Name: Age, dtype: float64

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
